# %% [markdown]
# ###### Assessment

# %% [markdown]
# ###### I am going to provide two .csv files , you are supposed to work on them and have to provide solutions to the following problems

# %% [markdown]
# ###### import necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ###### merge those two csv files (after getting as dataframes, get them as a single dataframe)

# %%
df1=pd.read_csv("/Users/alok.g.v/Desktop/python practice/Guvi Task/college_1.csv")
df2=pd.read_csv("/Users/alok.g.v/Desktop/python practice/Guvi Task/college_2.csv")
print(df1.shape)
print(df2.shape)
print(df1.head())
print(df2.head())
df=pd.concat([df2,df1])
df
# Out:
# (84, 7)
# (35, 9)
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
# 3  Mugunthan S   100.0   47.0              10610           10610
# 4  Sathammai.S   100.0    8.0               8980            8980
#
#                          Department  Rising
# 0  Computer Science and Engineering       0
# 1  Computer Science and Engineering       0
# 2  Computer Science and Engineering       0
# 3  Computer Science and Engineering       0
# 4  Computer Science and Engineering       0
#                 Name  python  python_en  mysql  computational_thinking  \
# 0      ASHOK KUMAR K     100          0     31                       9
# 1            Chandru       0         20      0                       0
# 2  Ganesh Ramkumar R      -1         55     24                       6
# ...

# %%
df.tail(20)
# Out:
#                Name  python  python_en   mysql  computational_thinking  \
# 64       k.parvathi   100.0        NaN  100.00                     NaN
# 65       jayapratha    82.0        NaN    0.00                     NaN
# 66   Evanasundari.K    61.0        NaN    0.00                     NaN
# 67         gousalya    56.0        NaN   27.00                     NaN
# 68      sivaranjini     0.0        NaN    3.75                     NaN
# 69       karthika.G   100.0        NaN    0.00                     NaN
# 70        vignesh B    82.0        NaN   20.00                     NaN
# 71      m.keerthana    97.5        NaN    0.00                     NaN
# 72       Subhashini   100.0        NaN    4.00                     NaN
# 73   rajesh kumar.r    30.0        NaN    0.00                     NaN
# 74  J.Bhuvaneshwari   100.0        NaN   20.00                     NaN
# 75         santhosh    82.0        NaN   12.00                     NaN
# ...

# %% [markdown]
# ###### Take each csv file , split that csv file into multiple categories (example csv files are added in the repo)

# %% [markdown]
# ###### consider if the codekata score exceeds 15000 points(present week) then make a csv on those observations as Exceeded expectations.csv

# %% [markdown]
# ###### if  10000<codekata score<15000   (Reached_expectations.csv)

# %% [markdown]
# ###### if  7000<codekata score<10000   (Needs_Improvement.csv)

# %% [markdown]
# ###### if  codekate score < 7000        (Unsatisfactory.csv)

# %%
df_exd_exp=df[df["CodeKata Score"]>=15000]
print(df_exd_exp)
df_exd_exp.to_csv("/Users/alok.g.v/Desktop/python practice/Guvi Task/Exceeded expectations.csv")
df_rec_exp=df[(df["CodeKata Score"]>=10000) & (df["CodeKata Score"]<=15000)]
print("reached exp",df_rec_exp)
df_rec_exp.to_csv("/Users/alok.g.v/Desktop/python practice/Guvi Task/Reached expectations.csv")
df_need_impv=df[(df["CodeKata Score"]>=7000) & (df["CodeKata Score"]<=10000)]
print("need improvement",df_need_impv)
df_need_impv.to_csv("/Users/alok.g.v/Desktop/python practice/Guvi Task/Need improvement.csv")
df_unsat=df[df["CodeKata Score"]<7000]
print("unsatisfied",df_unsat.head())
df_unsat.to_csv("/Users/alok.g.v/Desktop/python practice/Guvi Task/Unsatisfactory.csv")
# Out:
#             Name  python  python_en  mysql  computational_thinking  \
# 0  ASHOK KUMAR K   100.0        0.0   31.0                     9.0
# 0      A.Dharani    82.0        NaN   20.0                     NaN
# 1    V.JEEVITHA     82.0        NaN   20.0                     NaN
# 2    HEMAVATHI.R   100.0        NaN  100.0                     NaN
#
#    Previous Geekions  CodeKata Score                              Department  \
# 0              19400           19400  Electronics and Electrical Engineering
# 0              24500           24500        Computer Science and Engineering
# 1              21740           21740        Computer Science and Engineering
# 2              19680           19680        Computer Science and Engineering
#
#    Rising
# 0       0
# 0       0
# 1       0
# 2       0
# reached exp                 Name  python  python_en  mysql  computational_thinking  \
# 1            Chandru     0.0       20.0    0.0                     0.0
# ...

# %% [markdown]
# ###### Average of previous week geekions vs this week geekions (i.e Previous Geekions vs CodeKata Score)

# %%
df["avg_score"]=(df["CodeKata Score"]-df["Previous Geekions"])/2
df.head()
# Out:
#                 Name  python  python_en  mysql  computational_thinking  \
# 0      ASHOK KUMAR K   100.0        0.0   31.0                     9.0
# 1            Chandru     0.0       20.0    0.0                     0.0
# 2  Ganesh Ramkumar R    -1.0       55.0   24.0                     6.0
# 3    Bodipudi Harini    -1.0        0.0   35.0                    -1.0
# 4          VIINU V P    -1.0      100.0   24.0                    -1.0
#
#    Previous Geekions  CodeKata Score  \
# 0              19400           19400
# 1              14150           14490
# 2               8790           10790
# 3              10040           10040
# 4               9150            9150
#
#                                   Department  Rising  avg_score
# 0     Electronics and Electrical Engineering       0        0.0
# 1           Computer Science and Engineering     340      170.0
# 2           Computer Science and Engineering    2000     1000.0
# ...

# %% [markdown]
# ###### No of students participated

# %%
df["Name"].count()
# Out:
# 119

# %% [markdown]
# ###### #Average completion of python course or my_sql or python english or computational thinking

# %%
print("AVG Python:",df['python'].mean())
print("AVG my sql:",df["mysql"].mean())
print("AVG python english",df["python_en"].mean())
print("AVG computational thinking :",df["computational_thinking"].mean())
# Out:
# AVG Python: 54.35294117647059
# AVG my sql: 23.5
# AVG python english 29.65714285714286
# AVG computational thinking : 2.2

# %% [markdown]
# ###### rising star of the week (top 3 candidate who performed well in that particular week)

# %%
df.sort_values(by=['CodeKata Score'],ascending=False).head(3)
# Out:
#           Name  python  python_en  mysql  computational_thinking  \
# 0    A.Dharani    82.0        NaN   20.0                     NaN
# 1  V.JEEVITHA     82.0        NaN   20.0                     NaN
# 2  HEMAVATHI.R   100.0        NaN  100.0                     NaN
#
#    Previous Geekions  CodeKata Score                        Department  \
# 0              24500           24500  Computer Science and Engineering
# 1              21740           21740  Computer Science and Engineering
# 2              19680           19680  Computer Science and Engineering
#
#    Rising  avg_score
# 0       0        0.0
# 1       0        0.0
# 2       0        0.0

# %% [markdown]
# ###### Shining stars of the week (top 3 candidates who has highest geekions)

# %% [markdown]
# ###### Department wise codekata performence (pie chart)

# %%
from collections import Counter
print(Counter(df["Department"]))
dep_type=df.groupby('Department').count()
dep_type=dep_type.drop(["python","python_en","mysql","computational_thinking","Previous Geekions","CodeKata Score","Rising","avg_score"],axis=1)
print(dep_type)
plot = dep_type.plot.pie(y='Name', figsize=(5, 5))
plot
# Out:
# Counter({'Computer Science and Engineering': 63, 'Electronics and Communication Engineering': 39, 'Electronics and Electrical Engineering': 17})
#                                            Name
# Department
# Computer Science and Engineering             63
# Electronics and Communication Engineering    39
# Electronics and Electrical Engineering       17
# <AxesSubplot:ylabel='Name'>

# %% [markdown]
# ###### Department wise toppers (horizantal bar graph or any visual representations of your choice)

# %%
df.plot.bar(x="Department",y="CodeKata Score",alpha=.9)
# Out:
# <AxesSubplot:xlabel='Department'>
