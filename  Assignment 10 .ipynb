# %%
import pandas as pd
import numpy as np 
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier

# %%
data_train=pd.read_csv("/Users/alok.g.v/Desktop/python practice/Guvi Task/Task7/Assignment10_data/trainKNN.txt",sep=',',header=None,
                       names=['id number','refractive index','Na: Sodium','Mg: Magnesium','Al: Aluminum','Si: Silicon',' K: Potassium',
                             'Ca: Calcium','Ba: Barium','Fe: Iron','Type of glass'],index_col=0)
data_train
# Out:
#            refractive index  Na: Sodium  Mg: Magnesium  Al: Aluminum  \
# id number
# 1                   1.52101       13.64           4.49          1.10
# 2                   1.51761       13.89           3.60          1.36
# 3                   1.51618       13.53           3.55          1.54
# 4                   1.51766       13.21           3.69          1.29
# 5                   1.51742       13.27           3.62          1.24
# ...                     ...         ...            ...           ...
# 207                 1.51645       14.94           0.00          1.87
# 208                 1.51831       14.39           0.00          1.82
# 209                 1.51640       14.37           0.00          2.74
# 210                 1.51623       14.14           0.00          2.88
# 211                 1.51685       14.92           0.00          1.99
#
#            Si: Silicon   K: Potassium  Ca: Calcium  Ba: Barium  Fe: Iron  \
# id number
# ...

# %%
x=['refractive index','Na: Sodium','Mg: Magnesium','Al: Aluminum','Si: Silicon',' K: Potassium',
                             'Ca: Calcium','Ba: Barium','Fe: Iron']
y=['Type of glass']

# %%
X=data_train[x]
y=data_train[y]

# %%
scaler=StandardScaler()
X=scaler.fit_transform(X)
print(X,y)
# Out:
# [[ 0.89081203  0.3389847   1.24616006 ... -0.11334995 -0.33935667
#   -0.5834224 ]
#  [-0.22479561  0.65902807  0.60544985 ... -0.76221546 -0.33935667
#   -0.5834224 ]
#  [-0.69400706  0.19816562  0.56945489 ... -0.79747989 -0.33935667
#   -0.5834224 ]
#  ...
#  [-0.62182068  1.27351132 -1.98618697 ...  0.38035207  0.77644048
#   -0.5834224 ]
#  [-0.67760106  0.97907143 -1.98618697 ...  0.18992414  1.8509118
#   -0.5834224 ]
#  [-0.47416673  1.97760672 -1.98618697 ... -0.36020096  2.94604604
#   -0.5834224 ]]            Type of glass
# id number
# 1                      1
# 2                      1
# 3                      1
# 4                      1
# 5                      1
# ...                  ...
# 207                    7
# 208                    7
# 209                    7
# 210                    7
# 211                    7
#
# [196 rows x 1 columns]

# %%
data_test=pd.read_csv('/Users/alok.g.v/Desktop/python practice/Guvi Task/Task7/Assignment10_data/testKNN.txt',header=None,names=['id number','refractive index','Na: Sodium','Mg: Magnesium','Al: Aluminum','Si: Silicon',' K: Potassium',
                             'Ca: Calcium','Ba: Barium','Fe: Iron','Type of glass'],index_col=0)
data_test
# Out:
#            refractive index  Na: Sodium  Mg: Magnesium  Al: Aluminum  \
# id number
# 68                  1.52152       13.05           3.65          0.87
# 69                  1.52152       13.12           3.58          0.90
# 70                  1.52300       13.31           3.58          0.82
# 144                 1.51709       13.00           3.47          1.79
# 145                 1.51660       12.99           3.18          1.23
# 146                 1.51839       12.85           3.67          1.24
# 161                 1.51832       13.33           3.34          1.54
# 162                 1.51934       13.64           3.54          0.75
# 163                 1.52211       14.19           3.78          0.91
# 174                 1.52043       13.38           0.00          1.40
# 175                 1.52058       12.85           1.61          2.17
# 176                 1.52119       12.97           0.33          1.51
# ...

# %%
X_test=data_test[x]
y_test=data_test['Type of glass']
print(X_test,y_test)
# Out:
#            refractive index  Na: Sodium  Mg: Magnesium  Al: Aluminum  \
# id number
# 68                  1.52152       13.05           3.65          0.87
# 69                  1.52152       13.12           3.58          0.90
# 70                  1.52300       13.31           3.58          0.82
# 144                 1.51709       13.00           3.47          1.79
# 145                 1.51660       12.99           3.18          1.23
# 146                 1.51839       12.85           3.67          1.24
# 161                 1.51832       13.33           3.34          1.54
# 162                 1.51934       13.64           3.54          0.75
# 163                 1.52211       14.19           3.78          0.91
# 174                 1.52043       13.38           0.00          1.40
# 175                 1.52058       12.85           1.61          2.17
# 176                 1.52119       12.97           0.33          1.51
# ...

# %%
X_test=scaler.fit_transform(X_test)
X_test
# Out:
# array([[ 0.88089538, -0.67745268,  1.04449191, -0.83588893, -0.57678658,
#         -0.24795484,  0.29029673, -0.48794184,  0.24628886],
#        [ 0.88089538, -0.61097368,  1.00332645, -0.7827854 , -0.71521535,
#         -0.09271355,  0.26793435, -0.48794184,  0.18384943],
#        [ 1.4266408 , -0.43053068,  1.00332645, -0.92439482, -0.95746572,
#         -0.5196271 ,  0.5288287 , -0.48794184, -0.62786315],
#        [-0.7526534 , -0.72493768,  0.93863786,  0.79261939, -0.11535732,
#          1.57613032, -0.95454202, -0.48794184, -0.81518144],
#        [-0.93333938, -0.73443468,  0.76809524, -0.19864655,  0.17303597,
#          1.26564774, -0.48493219, -0.48794184,  0.68336487],
#        [-0.27328243, -0.86739269,  1.05625347, -0.18094537, -0.28839329,
#          1.42088903, -0.58183581, -0.48794184,  1.3701986 ],
#        [-0.29909471, -0.41153668,  0.86218772,  0.35008995, -0.78442974,
#          1.1880271 , -0.35075796, -0.48794184, -0.81518144],
# ...

# %%
def knn_e(k):
    knc_e=KNeighborsClassifier(n_neighbors=k,metric='euclidean')
    knc_e.fit(X,y)
    y_pred=knc_e.predict(X_test)
    acc=accuracy_score(y_test,y_pred)
    print(f'Number of Neighbors : {k}  accuracy : {acc}')

# %%
for x in range(1,11,2):
    knn_e(x)
# Out:
# Number of Neighbors : 1  accuracy : 0.6666666666666666
# Number of Neighbors : 3  accuracy : 0.6666666666666666
# Number of Neighbors : 5  accuracy : 0.6111111111111112
# Number of Neighbors : 7  accuracy : 0.6111111111111112
# Number of Neighbors : 9  accuracy : 0.6111111111111112
# /Users/alok.g.v/opt/anaconda3/lib/python3.8/site-packages/sklearn/neighbors/_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /Users/alok.g.v/opt/anaconda3/lib/python3.8/site-packages/sklearn/neighbors/_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# ...

# %%
def knn_m(k):
    knc_m=KNeighborsClassifier(n_neighbors=k,metric='manhattan')
    knc_m.fit(X,y)
    y_pred=knc_m.predict(X_test)
    acc=accuracy_score(y_test,y_pred)
    print(f'Number of Neighbors : {k}  accuracy : {acc}')

# %%
for x in range(1,11,2):
    knn_m(x)
# Out:
# Number of Neighbors : 1  accuracy : 0.6666666666666666
# Number of Neighbors : 3  accuracy : 0.5555555555555556
# Number of Neighbors : 5  accuracy : 0.6111111111111112
# Number of Neighbors : 7  accuracy : 0.6111111111111112
# Number of Neighbors : 9  accuracy : 0.6111111111111112
# /Users/alok.g.v/opt/anaconda3/lib/python3.8/site-packages/sklearn/neighbors/_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /Users/alok.g.v/opt/anaconda3/lib/python3.8/site-packages/sklearn/neighbors/_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# ...
